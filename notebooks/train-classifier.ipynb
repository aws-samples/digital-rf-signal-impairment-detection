# %% [markdown]
# Data Science

# %%
# !pip install autogluon
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 483.9 kB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 686.8 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 526.1 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 8.9 MB/s eta 0:00:000:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 17.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 2.0 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

df = pd.read_csv('training_data.csv')
df = df.drop('Unnamed: 0', axis=1)

train_data = TabularDataset(df)

# Specify the label column
label = 'class'

# Use AutoGluon to train a classification model
predictor = TabularPredictor(label=label).fit(train_data)
predictor.fit_summary()
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240129_192218"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240129_192218"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# ...

# %%
predictor.leaderboard(df, silent=True)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0            LightGBMXT    1.000000   1.000000    accuracy        0.048025
# 1   WeightedEnsemble_L2    1.000000   1.000000    accuracy        0.052651
# 2        ExtraTreesEntr    1.000000   1.000000    accuracy        0.137972
# 3        ExtraTreesGini    1.000000   1.000000    accuracy        0.145352
# 4              LightGBM    0.999231   0.996154    accuracy        0.043229
# 5         LightGBMLarge    0.997692   0.988462    accuracy        0.252274
# 6      RandomForestEntr    0.996923   0.984615    accuracy        0.136116
# 7      RandomForestGini    0.996923   0.984615    accuracy        0.143140
# 8        NeuralNetTorch    0.996154   0.992308    accuracy        0.025890
# 9               XGBoost    0.990769   0.988462    accuracy        0.049556
# 10             CatBoost    0.986923   0.988462    accuracy        0.007069
# ...

# %%
predictor.feature_importance(data=df)
# Out:
# Computing feature importance via permutation shuffling for 9 features using 1300 rows with 5 shuffle sets...
# 	3.02s	= Expected runtime (0.6s per shuffle set)
# 	1.88s	= Actual runtime (Completed 5 of 5 shuffle sets)
#              importance    stddev       p_value  n  p99_high   p99_low
# density_avg    0.232154  0.014989  2.073841e-06  5  0.263017  0.201291
# density_std    0.138923  0.009632  2.755648e-06  5  0.158756  0.119090
# ratio_avg      0.127538  0.005027  2.889349e-07  5  0.137888  0.117189
# blobs_4        0.101385  0.007079  2.834447e-06  5  0.115961  0.086808
# rotation       0.098923  0.008278  5.828955e-06  5  0.115967  0.081879
# blobs_32       0.022923  0.003236  4.643104e-05  5  0.029587  0.016260
# ratio_std      0.004923  0.000688  4.460827e-05  5  0.006340  0.003506
# blobs_16       0.000615  0.000344  8.065045e-03  5  0.001324 -0.000093
# blobs_8        0.000000  0.000000  5.000000e-01  5  0.000000  0.000000

# %%
predictor = TabularPredictor.load("./AutogluonModels/ag-20240129_192218/")

# Make predictions on new data
new_data = pd.DataFrame({
    'density_avg': [126576.71443267688],
    'density_std': [12331.48136114595],
    'ratio_avg': [1.0421287905177687],
    'ratio_std': [0.017569486744008087],
    'rotation': [0.5],
    'blobs_4': [1],
    'blobs_8': [0],
    'blobs_16': [0],
    'blobs_32': [0]
})
predictions = predictor.predict(new_data)
print(predictions)
# Out:
# 0    normal
# Name: class, dtype: object
