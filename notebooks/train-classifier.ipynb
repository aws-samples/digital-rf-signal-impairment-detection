# %% [markdown]
# conda_python3, ml.m5.xlarge

# %%
# !pip install autogluon

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

df = pd.read_csv('training_data.csv')
df = df.drop('Unnamed: 0', axis=1)

train_data = TabularDataset(df)

# Specify the label column
label = 'class'

# Use AutoGluon to train a classification model
predictor = TabularPredictor(label=label).fit(train_data)
predictor.fit_summary()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# No path specified. Models will be saved in: "AutogluonModels/ag-20240130_150521"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20240130_150521"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Wed Sep 6 21:15:41 UTC 2023
# CPU Count:          4
# Memory Avail:       13.13 GB / 15.32 GB (85.7%)
# Disk Space Avail:   13.76 GB / 14.60 GB (94.2%)
# ===================================================
# Train Data Rows:    1300
# Train Data Columns: 9
# Label Column:       class
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	4 unique label values:  ['compression', 'normal', 'phase_noise', 'interference']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 4
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13450.20 MB
# 	Train Data (Original)  Memory Usage: 0.05 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])  : 4 | ['blobs_4', 'blobs_8', 'blobs_16', 'blobs_32']
# 		('float', []) : 5 | ['density_avg', 'density_std', 'ratio_avg', 'ratio_std', 'rotation']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 5 | ['density_avg', 'density_std', 'ratio_avg', 'ratio_std', 'rotation']
# 		('int', ['bool']) : 4 | ['blobs_4', 'blobs_8', 'blobs_16', 'blobs_32']
# 	0.1s = Fit runtime
# 	9 features in original data used to generate 9 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.05 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 1040, Val Rows: 260
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 	0.8423	 = Validation score   (accuracy)
# 	1.76s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.85	 = Validation score   (accuracy)
# 	0.07s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 5: early stopping
# 	0.9346	 = Validation score   (accuracy)
# 	2.05s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	1.0	 = Validation score   (accuracy)
# 	1.2s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.9962	 = Validation score   (accuracy)
# 	0.79s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.9846	 = Validation score   (accuracy)
# 	0.85s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.9846	 = Validation score   (accuracy)
# 	0.81s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.9885	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	1.0	 = Validation score   (accuracy)
# 	0.78s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	1.0	 = Validation score   (accuracy)
# 	0.79s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.9923	 = Validation score   (accuracy)
# 	0.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	1.0	 = Validation score   (accuracy)
# 	2.71s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.9885	 = Validation score   (accuracy)
# 	2.44s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBMXT': 1.0}
# 	1.0	 = Validation score   (accuracy)
# 	0.82s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 17.79s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240130_150521")
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val eval_metric  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0            LightGBMXT   1.000000    accuracy       0.006183  1.196312                0.006183           1.196312            1       True          4
# 1   WeightedEnsemble_L2   1.000000    accuracy       0.007004  2.018980                0.000821           0.822668            2       True         14
# 2        NeuralNetTorch   1.000000    accuracy       0.009823  2.708964                0.009823           2.708964            1       True         12
# 3        ExtraTreesGini   1.000000    accuracy       0.087510  0.780786                0.087510           0.780786            1       True          9
# 4        ExtraTreesEntr   1.000000    accuracy       0.087756  0.790945                0.087756           0.790945            1       True         10
# 5              LightGBM   0.996154    accuracy       0.005005  0.787217                0.005005           0.787217            1       True          5
# 6               XGBoost   0.992308    accuracy       0.005977  0.619823                0.005977           0.619823            1       True         11
# 7              CatBoost   0.988462    accuracy       0.001907  0.957667                0.001907           0.957667            1       True          8
# 8         LightGBMLarge   0.988462    accuracy       0.024755  2.435806                0.024755           2.435806            1       True         13
# 9      RandomForestEntr   0.984615    accuracy       0.086818  0.810513                0.086818           0.810513            1       True          7
# 10     RandomForestGini   0.984615    accuracy       0.088917  0.847047                0.088917           0.847047            1       True          6
# 11      NeuralNetFastAI   0.934615    accuracy       0.010809  2.045357                0.010809           2.045357            1       True          3
# 12       KNeighborsDist   0.850000    accuracy       0.015471  0.066833                0.015471           0.066833            1       True          2
# 13       KNeighborsUnif   0.842308    accuracy       0.016933  1.755859                0.016933           1.755859            1       True          1
# Number of models trained: 14
# Types of models trained:
# {'XTModel', 'TabularNeuralNetTorchModel', 'WeightedEnsembleModel', 'CatBoostModel', 'KNNModel', 'NNFastAiTabularModel', 'LGBModel', 'RFModel', 'XGBoostModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 5 | ['density_avg', 'density_std', 'ratio_avg', 'ratio_std', 'rotation']
# ('int', ['bool']) : 4 | ['blobs_4', 'blobs_8', 'blobs_16', 'blobs_32']
# Plot summary of models saved to file: AutogluonModels/ag-20240130_150521SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif': 'KNNModel',
#   'KNeighborsDist': 'KNNModel',
#   'NeuralNetFastAI': 'NNFastAiTabularModel',
#   'LightGBMXT': 'LGBModel',
#   'LightGBM': 'LGBModel',
#   'RandomForestGini': 'RFModel',
#   'RandomForestEntr': 'RFModel',
#   'CatBoost': 'CatBoostModel',
#   'ExtraTreesGini': 'XTModel',
#   'ExtraTreesEntr': 'XTModel',
#   'XGBoost': 'XGBoostModel',
#   'NeuralNetTorch': 'TabularNeuralNetTorchModel',
#   'LightGBMLarge': 'LGBModel',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif': 0.8423076923076923,
#   'KNeighborsDist': 0.85,
#   'NeuralNetFastAI': 0.9346153846153846,
#   'LightGBMXT': 1.0,
#   'LightGBM': 0.9961538461538462,
#   'RandomForestGini': 0.9846153846153847,
#   'RandomForestEntr': 0.9846153846153847,
#   'CatBoost': 0.9884615384615385,
#   'ExtraTreesGini': 1.0,
#   'ExtraTreesEntr': 1.0,
#   'XGBoost': 0.9923076923076923,
#   'NeuralNetTorch': 1.0,
#   'LightGBMLarge': 0.9884615384615385,
#   'WeightedEnsemble_L2': 1.0},
#  'model_best': 'WeightedEnsemble_L2',
#  'model_paths': {'KNeighborsUnif': ['KNeighborsUnif'],
#   'KNeighborsDist': ['KNeighborsDist'],
#   'NeuralNetFastAI': ['NeuralNetFastAI'],
#   'LightGBMXT': ['LightGBMXT'],
#   'LightGBM': ['LightGBM'],
#   'RandomForestGini': ['RandomForestGini'],
#   'RandomForestEntr': ['RandomForestEntr'],
#   'CatBoost': ['CatBoost'],
#   'ExtraTreesGini': ['ExtraTreesGini'],
#   'ExtraTreesEntr': ['ExtraTreesEntr'],
#   'XGBoost': ['XGBoost'],
#   'NeuralNetTorch': ['NeuralNetTorch'],
#   'LightGBMLarge': ['LightGBMLarge'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2']},
#  'model_fit_times': {'KNeighborsUnif': 1.755859136581421,
#   'KNeighborsDist': 0.06683349609375,
#   'NeuralNetFastAI': 2.0453567504882812,
#   'LightGBMXT': 1.1963121891021729,
#   'LightGBM': 0.7872171401977539,
#   'RandomForestGini': 0.8470468521118164,
#   'RandomForestEntr': 0.8105134963989258,
#   'CatBoost': 0.957667350769043,
#   'ExtraTreesGini': 0.7807862758636475,
#   'ExtraTreesEntr': 0.7909450531005859,
#   'XGBoost': 0.6198232173919678,
#   'NeuralNetTorch': 2.7089641094207764,
#   'LightGBMLarge': 2.4358057975769043,
#   'WeightedEnsemble_L2': 0.8226675987243652},
#  'model_pred_times': {'KNeighborsUnif': 0.016933441162109375,
#   'KNeighborsDist': 0.015471458435058594,
#   'NeuralNetFastAI': 0.01080942153930664,
#   'LightGBMXT': 0.006183147430419922,
#   'LightGBM': 0.0050048828125,
#   'RandomForestGini': 0.08891677856445312,
#   'RandomForestEntr': 0.08681821823120117,
#   'CatBoost': 0.0019068717956542969,
#   'ExtraTreesGini': 0.0875101089477539,
#   'ExtraTreesEntr': 0.08775639533996582,
#   'XGBoost': 0.005976676940917969,
#   'NeuralNetTorch': 0.009822607040405273,
#   'LightGBMLarge': 0.02475452423095703,
#   'WeightedEnsemble_L2': 0.0008211135864257812},
#  'num_bag_folds': 0,
#  'max_stack_level': 2,
#  'num_classes': 4,
#  'model_hyperparams': {'KNeighborsUnif': {'weights': 'uniform'},
#   'KNeighborsDist': {'weights': 'distance'},
#   'NeuralNetFastAI': {'layers': None,
#    'emb_drop': 0.1,
#    'ps': 0.1,
#    'bs': 'auto',
#    'lr': 0.01,
#    'epochs': 'auto',
#    'early.stopping.min_delta': 0.0001,
#    'early.stopping.patience': 20,
#    'smoothing': 0.0},
#   'LightGBMXT': {'learning_rate': 0.05, 'extra_trees': True},
#   'LightGBM': {'learning_rate': 0.05},
#   'RandomForestGini': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'RandomForestEntr': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'CatBoost': {'iterations': 10000,
#    'learning_rate': 0.05,
#    'random_seed': 0,
#    'allow_writing_files': False,
#    'eval_metric': 'Accuracy'},
#   'ExtraTreesGini': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'gini'},
#   'ExtraTreesEntr': {'n_estimators': 300,
#    'max_leaf_nodes': 15000,
#    'n_jobs': -1,
#    'random_state': 0,
#    'bootstrap': True,
#    'criterion': 'entropy'},
#   'XGBoost': {'n_estimators': 10000,
#    'learning_rate': 0.1,
#    'n_jobs': -1,
#    'proc.max_category_levels': 100,
#    'objective': 'multi:softprob',
#    'booster': 'gbtree',
#    'num_class': 4},
#   'NeuralNetTorch': {'num_epochs': 500,
#    'epochs_wo_improve': 20,
#    'activation': 'relu',
#    'embedding_size_factor': 1.0,
#    'embed_exponent': 0.56,
#    'max_embedding_dim': 100,
#    'y_range': None,
#    'y_range_extend': 0.05,
#    'dropout_prob': 0.1,
#    'optimizer': 'adam',
#    'learning_rate': 0.0003,
#    'weight_decay': 1e-06,
#    'proc.embed_min_categories': 4,
#    'proc.impute_strategy': 'median',
#    'proc.max_category_levels': 100,
#    'proc.skew_threshold': 0.99,
#    'use_ngram_features': False,
#    'num_layers': 4,
#    'hidden_size': 128,
#    'max_batch_size': 512,
#    'use_batchnorm': False,
#    'loss_function': 'auto'},
#   'LightGBMLarge': {'learning_rate': 0.03,
#    'num_leaves': 128,
#    'feature_fraction': 0.9,
#    'min_data_in_leaf': 3},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                   model  score_val eval_metric  pred_time_val  fit_time  \
#  0            LightGBMXT   1.000000    accuracy       0.006183  1.196312
#  1   WeightedEnsemble_L2   1.000000    accuracy       0.007004  2.018980
#  2        NeuralNetTorch   1.000000    accuracy       0.009823  2.708964
#  3        ExtraTreesGini   1.000000    accuracy       0.087510  0.780786
#  4        ExtraTreesEntr   1.000000    accuracy       0.087756  0.790945
#  5              LightGBM   0.996154    accuracy       0.005005  0.787217
#  6               XGBoost   0.992308    accuracy       0.005977  0.619823
#  7              CatBoost   0.988462    accuracy       0.001907  0.957667
#  8         LightGBMLarge   0.988462    accuracy       0.024755  2.435806
#  9      RandomForestEntr   0.984615    accuracy       0.086818  0.810513
#  10     RandomForestGini   0.984615    accuracy       0.088917  0.847047
#  11      NeuralNetFastAI   0.934615    accuracy       0.010809  2.045357
#  12       KNeighborsDist   0.850000    accuracy       0.015471  0.066833
#  13       KNeighborsUnif   0.842308    accuracy       0.016933  1.755859
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.006183           1.196312            1       True
#  1                 0.000821           0.822668            2       True
#  2                 0.009823           2.708964            1       True
#  3                 0.087510           0.780786            1       True
#  4                 0.087756           0.790945            1       True
#  5                 0.005005           0.787217            1       True
#  6                 0.005977           0.619823            1       True
#  7                 0.001907           0.957667            1       True
#  8                 0.024755           2.435806            1       True
#  9                 0.086818           0.810513            1       True
#  10                0.088917           0.847047            1       True
#  11                0.010809           2.045357            1       True
#  12                0.015471           0.066833            1       True
#  13                0.016933           1.755859            1       True
#
#      fit_order
#  0           4
#  1          14
#  2          12
#  3           9
#  4          10
#  5           5
#  6          11
#  7           8
#  8          13
#  9           7
#  10          6
#  11          3
#  12          2
#  13          1  }

# %%
predictor.leaderboard(df, silent=True)
# Out:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0        NeuralNetTorch    1.000000   1.000000    accuracy        0.015611
# 1            LightGBMXT    1.000000   1.000000    accuracy        0.025489
# 2   WeightedEnsemble_L2    1.000000   1.000000    accuracy        0.028409
# 3        ExtraTreesGini    1.000000   1.000000    accuracy        0.117021
# 4        ExtraTreesEntr    1.000000   1.000000    accuracy        0.119910
# 5              LightGBM    0.999231   0.996154    accuracy        0.022076
# 6               XGBoost    0.998462   0.992308    accuracy        0.034707
# 7         LightGBMLarge    0.997692   0.988462    accuracy        0.172749
# 8      RandomForestEntr    0.996923   0.984615    accuracy        0.114683
# 9      RandomForestGini    0.996923   0.984615    accuracy        0.115591
# 10             CatBoost    0.986923   0.988462    accuracy        0.003762
# 11       KNeighborsDist    0.970000   0.850000    accuracy        0.014317
# 12      NeuralNetFastAI    0.936923   0.934615    accuracy        0.029220
# 13       KNeighborsUnif    0.870769   0.842308    accuracy        0.014449
#
#     pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.009823  2.708964                 0.015611                0.009823
# 1        0.006183  1.196312                 0.025489                0.006183
# 2        0.007004  2.018980                 0.002921                0.000821
# 3        0.087510  0.780786                 0.117021                0.087510
# 4        0.087756  0.790945                 0.119910                0.087756
# 5        0.005005  0.787217                 0.022076                0.005005
# 6        0.005977  0.619823                 0.034707                0.005977
# 7        0.024755  2.435806                 0.172749                0.024755
# 8        0.086818  0.810513                 0.114683                0.086818
# 9        0.088917  0.847047                 0.115591                0.088917
# 10       0.001907  0.957667                 0.003762                0.001907
# 11       0.015471  0.066833                 0.014317                0.015471
# 12       0.010809  2.045357                 0.029220                0.010809
# 13       0.016933  1.755859                 0.014449                0.016933
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            2.708964            1       True         12
# 1            1.196312            1       True          4
# 2            0.822668            2       True         14
# 3            0.780786            1       True          9
# 4            0.790945            1       True         10
# 5            0.787217            1       True          5
# 6            0.619823            1       True         11
# 7            2.435806            1       True         13
# 8            0.810513            1       True          7
# 9            0.847047            1       True          6
# 10           0.957667            1       True          8
# 11           0.066833            1       True          2
# 12           2.045357            1       True          3
# 13           1.755859            1       True          1

# %%
predictor.feature_importance(data=df)
# Out:
# Computing feature importance via permutation shuffling for 9 features using 1300 rows with 5 shuffle sets...
# 	1.59s	= Expected runtime (0.32s per shuffle set)
# 	1.05s	= Actual runtime (Completed 5 of 5 shuffle sets)
#              importance    stddev       p_value  n  p99_high   p99_low
# density_avg    0.225231  0.015475  2.657265e-06  5  0.257093  0.193368
# density_std    0.157538  0.010426  2.288484e-06  5  0.179005  0.136072
# ratio_avg      0.142769  0.005428  2.503176e-07  5  0.153946  0.131592
# blobs_4        0.098308  0.006422  2.172983e-06  5  0.111531  0.085085
# rotation       0.094000  0.008130  6.647888e-06  5  0.110740  0.077260
# blobs_32       0.023231  0.002999  3.260252e-05  5  0.029406  0.017056
# ratio_std      0.003538  0.001167  1.233522e-03  5  0.005940  0.001136
# blobs_8        0.000000  0.000000  5.000000e-01  5  0.000000  0.000000
# blobs_16       0.000000  0.000000  5.000000e-01  5  0.000000  0.000000

# %%
predictor = TabularPredictor.load("./AutogluonModels/ag-20240130_150521/")

# Make predictions on new data
new_data = pd.DataFrame({
    'density_avg': [126576.71443267688],
    'density_std': [12331.48136114595],
    'ratio_avg': [1.0421287905177687],
    'ratio_std': [0.017569486744008087],
    'rotation': [0.5],
    'blobs_4': [1],
    'blobs_8': [0],
    'blobs_16': [0],
    'blobs_32': [0]
})
predictions = predictor.predict(new_data)
print(predictions)
# Out:
# 0    normal
# Name: class, dtype: object
